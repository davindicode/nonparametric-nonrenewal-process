# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator # for minor ticks
from matplotlib import gridspec
from matplotlib import patches
from matplotlib.offsetbox import TextArea, VPacker, AnnotationBbox
plt.style.use(['paper.mplstyle'])

import pickle

import sys
sys.path.append("../..")
from neuroprob import tools

# %%
cnt_tuples, isi_tuples, covariates, lower, mean, upper, brate, bhd_t, \
     T_DS_arrl, T_KS_arrl, traj_arr, T_DS_arrs, T_KS_arrs, I_arrs, pred_LL, \
     show_neuron, tbin, shift_times = pickle.load(open('./output/metric1.p', 'rb'))

# %%
fig = plt.figure(figsize=(8, 3.5))
ax.text(-0.3, 1.2, 'A', transform=ax.transAxes, size=15)
ax.text(-0.3, 1.2, 'B', transform=ax.transAxes, size=15)
ax.text(-0.3, 1.2, 'C', transform=ax.transAxes, size=15)


bins = np.linspace(0.0, 1.0, 16)



### Histogram Z values + dispersions

# Poisson
widths = [1, 1]
heights = [1, 3]
spec = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths,
                         height_ratios=heights, top=1., bottom=0.5, left=.0, right=.3)

q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS, _ = cnt_tuple_1

ax = fig.add_subplot(spec[0, 0])

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set_xlim(0.0, 1.0)
ax.set_xticks([])
ax.set_yticks([])
ax.hist(q_cdf, bins=bins, edgecolor='b', facecolor=(0.95, 0.95, 0.95), density=True)
ax.plot(bins, np.ones_like(bins), 'r--')
#ax.set_ylabel(r"$p(q)$", fontsize=12)
ax.set_title('count method', fontsize=12, pad=10)

ax = fig.add_subplot(spec[1, 0])
ax = stats.plot_dispersion(ax, q_cdf, s_KS, labelx=True, labely=True)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)
ax.set_xlabel(r'quantile $q$', labelpad=-10)
ax.set_ylabel('CDF')#, labelpad=-10)

q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS = isi_tuple_1

ax = fig.add_subplot(spec[0, 1])
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set_xlim(0.0, 1.0)
ax.set_xticks([])
ax.set_yticks([])
ax.hist(q_cdf, bins=bins, edgecolor='b', facecolor=(0.95, 0.95, 0.95), density=True)
ax.plot(bins, np.ones_like(bins), 'r--')
ax.set_title('ISI method', fontsize=12, pad=10)

ax = fig.add_subplot(spec[1, 1])
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)


# Gamma
widths = [1, 1]
heights = [1, 3]
spec = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths,
                         height_ratios=heights, top=1., bottom=0.5, left=.35, right=.65)

q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS, _ = cnt_tuple_2

ax = fig.add_subplot(spec[0, 0])

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set_xlim(0.0, 1.0)
ax.set_xticks([])
ax.set_yticks([])
ax.hist(q_cdf, bins=bins, edgecolor='b', facecolor=(0.95, 0.95, 0.95), density=True)
ax.plot(bins, np.ones_like(bins), 'r--')

ax = fig.add_subplot(spec[1, 0])
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)

q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS = isi_tuple_2

ax = fig.add_subplot(spec[0, 1])
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set_xlim(0.0, 1.0)
ax.set_xticks([])
ax.set_yticks([])
ax.hist(q_cdf, bins=bins, edgecolor='b', facecolor=(0.95, 0.95, 0.95), density=True)
ax.plot(bins, np.ones_like(bins), 'r--')


ax = fig.add_subplot(spec[1, 1])
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)


# Gamma
widths = [1, 1]
heights = [1, 3]
spec = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths,
                         height_ratios=heights, top=1., bottom=0.5, left=.7, right=1.)

q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS, _ = cnt_tuple_3

ax = fig.add_subplot(spec[0, 0])

ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set_xlim(0.0, 1.0)
ax.set_xticks([])
ax.set_yticks([])
ax.hist(q_cdf, bins=bins, edgecolor='b', facecolor=(0.95, 0.95, 0.95), density=True)
ax.plot(bins, np.ones_like(bins), 'r--')

ax = fig.add_subplot(spec[1, 0])
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)

q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS = isi_tuple_3

ax = fig.add_subplot(spec[0, 1])
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.set_xlim(0.0, 1.0)
ax.set_xticks([])
ax.set_yticks([])
ax.hist(q_cdf, bins=bins, edgecolor='b', facecolor=(0.95, 0.95, 0.95), density=True)
ax.plot(bins, np.ones_like(bins), 'r--')

ax = fig.add_subplot(spec[1, 1])
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)




widths = [1, 1]
heights = [1, 3]
spec = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths,
                         height_ratios=heights, top=1., bottom=0.5, left=.7, right=1.)

gs0 = fig.add_gridspec(2, 1)

gs00 = gs0[0].subgridspec(1, 4)
gs01 = gs0[1].subgridspec(1, 3)


alpha_s = 0.05
ref_sign_DS = sps.erfinv(1-alpha_s/2.)*np.sqrt(2)

# Empirical DS distributions
#fig.text(-0.12, 1.1, 'A', transform=fig.transFigure, size=15)
#fig.text(-0.425, 1.1, 'B', transform=fig.transFigure, size=15)



d = np.linspace(-2, 2, 100)
dd = np.linspace(-2, 2, 100)#+0.5

axes = fig.add_subplot(gs00[0, 0])
axes.xaxis.set_minor_locator(MultipleLocator(1))
#axes.set_xlim(-1.0, 2.0)
#axes.set_yticks([])

axes.hist(Z_DS_[0], bins=dd, density=True, facecolor='lightgray')
axes.plot(d, scstats.norm.pdf(d*ref_sign_DS)*ref_sign_DS, 'r-')


axes = fig.add_subplot(gs00[0, 1])
axes.xaxis.set_minor_locator(MultipleLocator(1))
axes.hist(Z_DS__[0], bins=dd, density=True, facecolor='lightgray')
axes.plot(d, scstats.norm.pdf(d*ref_sign_DS)*ref_sign_DS, 'r-')

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)

d = np.linspace(-2, 2, 100)
dd = np.linspace(-2, 2, 100)#+0.5

axes = fig.add_subplot(gs00[0, 2])
axes.xaxis.set_minor_locator(MultipleLocator(1))
#axes.set_xlim(-1.0, 2.0)
#axes.set_yticks([])

axes.hist(Z_DS_[1], bins=dd, density=True, facecolor='lightgray')
axes.plot(d, scstats.norm.pdf(d*ref_sign_DS)*ref_sign_DS, 'r-')


axes = fig.add_subplot(gs00[0, 3])
axes.xaxis.set_minor_locator(MultipleLocator(1))
axes.hist(Z_DS__[1], bins=dd, density=True, facecolor='lightgray')
axes.plot(d, scstats.norm.pdf(d*ref_sign_DS)*ref_sign_DS, 'r-')

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)







# export
#plt.savefig('output/methods_DS.svg')
#plt.savefig('output/methods_DS.pdf')
plt.show()

# %%
# modulation
widths = [1]
heights = [1]
spec = fig.add_gridspec(ncols=1, nrows=1, width_ratios=widths,
                         height_ratios=heights, left=0.02, right=0.31, top=.3, bottom=0.)

ax = fig.add_subplot(spec[0, 0])
ax.text(-0.2, 1.2, 'D', transform=ax.transAxes, size=15)

T = 5000
ax.plot(np.arange(T)*sample_bin, rate_fit*np.ones(T), 'tab:blue', linestyle='-.', label='homogeneous')
ax.plot(np.arange(T)*sample_bin, rate[0, :T], 'tab:purple', label='ground truth')
ax.legend()
ax.set_xlabel('time (s)', labelpad=-5)
ax.set_ylabel('rate (Hz)')
ax.set_xlim(0, 5)
ax.set_xticks([0, 5])
ax.set_title('reference Gamma process', size=12)


widths = [1, 1]
heights = [1]
spec = fig.add_gridspec(ncols=2, nrows=1, width_ratios=widths,
                         height_ratios=heights, left=0.39, right=.66, top=.3, bottom=0.)

fig.text(0.525, 0.35, 'homogeneous', ha='center', va='center', fontsize=12)
ax = fig.add_subplot(spec[0, 0])
q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS, _ = cnt_tuple_4
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)

ax = fig.add_subplot(spec[0, 1])
q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS = isi_tuple_4
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)


widths = [1, 1]
heights = [1]
spec = fig.add_gridspec(ncols=2, nrows=1, width_ratios=widths,
                         height_ratios=heights, left=0.73, right=1., top=.3, bottom=0.)

fig.text(0.875, 0.35, 'ground truth', ha='center', va='center', fontsize=12)
ax = fig.add_subplot(spec[0, 0])
q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS, _ = cnt_tuple_5
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)

ax = fig.add_subplot(spec[0, 1])
q_cdf, Z_DS, T_KS, s_DS, s_KS, p_DS, p_KS = isi_tuple_5
ax = stats.plot_dispersion(ax, q_cdf, s_KS)
ax.text(.05, .9, r'$T_{DS}=$'+r'{:.2f}'.format(Z_DS), va='center', ha='left', fontsize=11)

# %%
fig = plt.figure(figsize=(8, 5))
fig.text(-0.075, 1.0, 'A', transform=fig.transFigure, size=15)
fig.text(-0.075, 0.35, 'B', transform=fig.transFigure, size=15)

bins = np.linspace(0.5, 10.5, 100)
alpha = 0.05
T = [6000, 6000]
N = len(rate_modes)


### modulation
widths = [1]
heights = [1, 1]
spec = fig.add_gridspec(ncols=1, nrows=2, width_ratios=widths,
                        height_ratios=heights, left=0.02, right=.27, top=1., bottom=.5)

for n in range(N):
    
    ax = fig.add_subplot(spec[n, 0])
    
    if n == N-1:
        ax.set_xlabel('time')
    if n == N-2:
        ax.set_ylabel('rate (Hz)')
    ax.plot(np.arange(T[n])*sample_bin, rate_[n][0:T[n]])

    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.set_xticks([])
    
    if n == 0:
        ax.annotate("",
            xy=(0.0, 8.5), xycoords='data',
            xytext=(2.0, 8.5), textcoords='data',
            arrowprops=dict(arrowstyle="-", lw=3, 
                      connectionstyle="arc3, rad=0"),
            )
        ax.text(1.0, 9., '2 s', fontsize=14, ha='center')
        

widths = [1, 1]
heights = [1, 1]
spec = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, wspace=0.4, 
                        height_ratios=heights, left=0.4, right=1., top=1., bottom=0.5)

fig.text(0.635, 0.42, 'segment length (s)', fontsize=12)



### modulation type
for n in range(N):
    scores = scores_t[n]
    conf = conf_[n]
    bins = np.linspace(0.5, 10.5, len(conf))
    
    ax = fig.add_subplot(spec[n, 0])
    if n < N-1:
        ax.set_xticklabels([])
    if n == N-2:
        ax.set_ylabel('$T_{DS}$', fontsize=12)
    
    ax.errorbar(avg_len_[n], scores[:, :, 0].mean(1), yerr=scores[:, :, 0].std(1), marker='+', capsize=3, linestyle='')

    samples = (sim_samples*sample_bin/bins).astype(int)

    ax.set_xlim(0.5, 10.5)
    ax.fill_between(
        bins, -1.,
        1., color='grey', alpha=0.5
    )

    ax = fig.add_subplot(spec[n, 1])
    if n < N-1:
        #ax[n, 0].set_xticks([])
        ax.set_xticklabels([])

    ax.errorbar(avg_len_[n], scores[:, :, 1].mean(1), yerr=scores[:, :, 1].std(1), marker='+', capsize=3, linestyle='')

    ax.fill_between(
        bins, np.zeros_like(conf),
        conf, color='grey', alpha=0.5
    )
    ax.set_ylim(0)
    ax.set_xlim(0.5, 10.5)
    
    if n == N-2:
        ax.set_ylabel('$T_{KS}$')



    
#figtr = fig.transFigure
#ptB = figtr.transform(figtr.transform((0.35, 0.5)))
#ptE = figtr.transform(figtr.transform((0.4, 0.5)))

#arrow = patches.FancyArrowPatch(
#    ptB, ptE, transform=fig.transFigure,
#    fc = "black", arrowstyle='simple', alpha = 1.0,
#    mutation_scale = 30.
#)
#fig.patches.append(arrow)



### plot varying sinusoidal modulations
widths = [1, 0.7]
heights = [1]
spec = fig.add_gridspec(ncols=2, nrows=1, width_ratios=widths,
                        height_ratios=heights, left=0., right=.4, top=.3, bottom=0.)


# plot variation
ax = fig.add_subplot(spec[0, 0])
m_arr = [0, 5, 10]
plot_samples = 5000
ax.set_ylim(0., 20.)
ax.set_xlim(0, 5)
ax.set_ylabel('rate (Hz)')
ax.set_xlabel('time (s)')

for mod in m_arr:
    
    rate_0 = 10.0
    period = 2000
    rate = np.empty((plot_samples))
    for t in range(plot_samples):
        rate[t] = mod*np.sin(2*np.pi*t/period) + rate_0
        
    ax.plot(np.arange(plot_samples)*sample_bin, rate)


ax = fig.add_subplot(spec[0, 1])
bins = np.linspace(0.0, 1.0, 11)
ax.plot(bins, bins, 'r--')

for n in m_arr:
    samples = len(q[n][0])
    q_order = np.append(np.array([0]), np.sort(q[n][0]))
    bb = np.arange(0, samples+1)/samples
    ax.plot(q_order, bb, linewidth=4, alpha=0.5)

ax.set_xlim(0., 1.)
ax.set_ylim(0., 1.)
ax.set_aspect(1.)

tools.decorate_ax(ax)
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xlabel(r'quantile $q$')

    
### scores
widths = [1, 1]
heights = [1]
spec = fig.add_gridspec(ncols=2, nrows=1, width_ratios=widths,
                        height_ratios=heights, left=0.5, right=1., top=.3, bottom=0.)
    
ax = fig.add_subplot(spec[0, 0])

ax.set_title('count method', fontsize=12)
ax.errorbar(mod_arr, scores_mod[:, :, 0].mean(1), yerr=scores_mod[:, :, 0].std(1), \
            marker='+', capsize=3, linestyle='')
mod_arr_ = np.linspace(-0.2, 10.2, 10)

ax.set_xlim(mod_arr_[0], mod_arr_[-1])
ax.set_ylabel(r'$T_{DS}$', fontsize=12)

ax.fill_between(
    mod_arr_, -np.ones_like(mod_arr_),
    np.ones_like(mod_arr_), color='grey', alpha=0.5
)

ax = fig.add_subplot(spec[0, 1])

ax.set_title('ISI method', fontsize=12)
ax.errorbar(mod_arr, scores_mod[:, :, 1].mean(1), yerr=scores_mod[:, :, 1].std(1), \
            marker='+', capsize=3, linestyle='')

ax.set_xlim(mod_arr_[0], mod_arr_[-1])

bins = np.linspace(0.8, 10.2, 10)
ax.fill_between(
    mod_arr_, -np.ones_like(mod_arr_),
    np.ones_like(mod_arr_), color='grey', alpha=0.5
)

fig.text(0.75, -0.1, r'$r_m$ (Hz)', ha='center', fontsize=12)
fig.subplots_adjust(wspace=0.3)




# export
plt.savefig('output/T_statistics.svg')
plt.savefig('output/T_statistics.pdf')
plt.show()
